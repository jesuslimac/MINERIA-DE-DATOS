# %%
import pandas as pd

#importamos los datos "Accidentes de Transito en la Carretera de los años 2020 y 2021"
datos=pd.read_csv("ATEC20_21.csv")
datos
# Out:
#       FECHA_CORTE     FECHA   HORA   DEPARTAMENTO CODIGO_VÍA  KILOMETRO  \
# 0        20211222  20200101   5:40           LIMA      PE-1S       24.0
# 1        20211222  20200101  16:30      CAJAMARCA      PE-3N       74.0
# 2        20211222  20200101   7:45          PASCO      PE-3N      103.0
# 3        20211222  20200101  18:30      CAJAMARCA      PE-08      111.0
# 4        20211222  20200101  18:40           LIMA      PE-1N      174.0
# ...           ...       ...    ...            ...        ...        ...
# 8150     20211222  20210930   1:30         ANCASH      PE-1N      348.0
# 8151     20211222  20210930   4:00  MADRE DE DIOS     PE-30C      417.0
# 8152     20211222  20210930  15:10    LA LIBERTAD      PE-1N      627.0
# 8153     20211222  20210930   2:50     LAMBAYEQUE      PE-1N      758.0
# 8154     20211222  20210930  18:47           PUNO      PE-3S     1296.0
#
#      MODALIDAD  FALLECIDOS  HERIDOS
# 0     DESPISTE         0.0      0.0
# 1     DESPISTE         0.0      0.0
# 2     DESPISTE         0.0      1.0
# 3     DESPISTE         0.0      2.0
# 4     DESPISTE         0.0      5.0
# ...        ...         ...      ...
# 8150    CHOQUE         0.0      0.0
# 8151    CHOQUE         0.0      0.0
# 8152    CHOQUE         0.0      2.0
# 8153  DESPISTE         0.0      0.0
# 8154    CHOQUE         1.0      0.0
#
# [8155 rows x 9 columns]

# %%
#Dectectamos los datos nulos de la base de datos 
datos.isnull()
datos.notnull()
# Out:
#       FECHA_CORTE  FECHA  HORA  DEPARTAMENTO  CODIGO_VÍA  KILOMETRO  \
# 0            True   True  True          True        True       True
# 1            True   True  True          True        True       True
# 2            True   True  True          True        True       True
# 3            True   True  True          True        True       True
# 4            True   True  True          True        True       True
# ...           ...    ...   ...           ...         ...        ...
# 8150         True   True  True          True        True       True
# 8151         True   True  True          True        True       True
# 8152         True   True  True          True        True       True
# 8153         True   True  True          True        True       True
# 8154         True   True  True          True        True       True
#
#       MODALIDAD  FALLECIDOS  HERIDOS
# 0          True        True     True
# 1          True        True     True
# 2          True        True     True
# 3          True        True     True
# 4          True        True     True
# ...         ...         ...      ...
# 8150       True        True     True
# 8151       True        True     True
# 8152       True        True     True
# 8153       True        True     True
# 8154       True        True     True
#
# [8155 rows x 9 columns]

# %%
#Eliminamos las filas que contienen los datos nulos
datos.dropna()
print(datos)

#Mostrando las dimensiones de la tabla 
print('Las dimensiones de la tabla ahora son: ', datos.shape)
# Out:
#       FECHA_CORTE     FECHA   HORA   DEPARTAMENTO CODIGO_VÍA  KILOMETRO  \
# 0        20211222  20200101   5:40           LIMA      PE-1S       24.0
# 1        20211222  20200101  16:30      CAJAMARCA      PE-3N       74.0
# 2        20211222  20200101   7:45          PASCO      PE-3N      103.0
# 3        20211222  20200101  18:30      CAJAMARCA      PE-08      111.0
# 4        20211222  20200101  18:40           LIMA      PE-1N      174.0
# ...           ...       ...    ...            ...        ...        ...
# 8150     20211222  20210930   1:30         ANCASH      PE-1N      348.0
# 8151     20211222  20210930   4:00  MADRE DE DIOS     PE-30C      417.0
# 8152     20211222  20210930  15:10    LA LIBERTAD      PE-1N      627.0
# 8153     20211222  20210930   2:50     LAMBAYEQUE      PE-1N      758.0
# 8154     20211222  20210930  18:47           PUNO      PE-3S     1296.0
#
#      MODALIDAD  FALLECIDOS  HERIDOS
# 0     DESPISTE         0.0      0.0
# 1     DESPISTE         0.0      0.0
# 2     DESPISTE         0.0      1.0
# 3     DESPISTE         0.0      2.0
# 4     DESPISTE         0.0      5.0
# ...        ...         ...      ...
# 8150    CHOQUE         0.0      0.0
# 8151    CHOQUE         0.0      0.0
# 8152    CHOQUE         0.0      2.0
# 8153  DESPISTE         0.0      0.0
# 8154    CHOQUE         1.0      0.0
#
# [8155 rows x 9 columns]
# Las dimensiones de la tabla ahora son:  (8155, 9)

# %%
#Usamos describe para visualizar la descripccion de los datos
print(datos.describe)
# Out:
# <bound method NDFrame.describe of       FECHA_CORTE     FECHA   HORA   DEPARTAMENTO CODIGO_VÍA  KILOMETRO  \
# 0        20211222  20200101   5:40           LIMA      PE-1S       24.0
# 1        20211222  20200101  16:30      CAJAMARCA      PE-3N       74.0
# 2        20211222  20200101   7:45          PASCO      PE-3N      103.0
# 3        20211222  20200101  18:30      CAJAMARCA      PE-08      111.0
# 4        20211222  20200101  18:40           LIMA      PE-1N      174.0
# ...           ...       ...    ...            ...        ...        ...
# 8150     20211222  20210930   1:30         ANCASH      PE-1N      348.0
# 8151     20211222  20210930   4:00  MADRE DE DIOS     PE-30C      417.0
# 8152     20211222  20210930  15:10    LA LIBERTAD      PE-1N      627.0
# 8153     20211222  20210930   2:50     LAMBAYEQUE      PE-1N      758.0
# 8154     20211222  20210930  18:47           PUNO      PE-3S     1296.0
#
#      MODALIDAD  FALLECIDOS  HERIDOS
# 0     DESPISTE         0.0      0.0
# 1     DESPISTE         0.0      0.0
# 2     DESPISTE         0.0      1.0
# 3     DESPISTE         0.0      2.0
# 4     DESPISTE         0.0      5.0
# ...        ...         ...      ...
# 8150    CHOQUE         0.0      0.0
# 8151    CHOQUE         0.0      0.0
# 8152    CHOQUE         0.0      2.0
# 8153  DESPISTE         0.0      0.0
# 8154    CHOQUE         1.0      0.0
#
# [8155 rows x 9 columns]>

# %%
#Detectamos anomalias a travez de histogramas
datos.hist(color='blue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bf79fd2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bf7a183d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bf79cc810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bf7981d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bf7944250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bf78fa750>]],
#       dtype=object)
